# %% [markdown]
# ## Quantum walk code

# %%
# !python --version
# !pip install qiskit
# Out:
# Python 3.8.8
# Requirement already satisfied: qiskit in c:\users\h&r\appdata\roaming\python\python38\site-packages (0.29.1)
# Requirement already satisfied: qiskit-terra==0.18.2 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit) (0.18.2)
# Requirement already satisfied: qiskit-aqua==0.9.5 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit) (0.9.5)
# Requirement already satisfied: qiskit-aer==0.8.2 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit) (0.8.2)
# Requirement already satisfied: qiskit-ibmq-provider==0.16.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit) (0.16.0)
# Requirement already satisfied: qiskit-ignis==0.6.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit) (0.6.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aer==0.8.2->qiskit) (1.7.1)
# Requirement already satisfied: pybind11>=2.6 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aer==0.8.2->qiskit) (2.7.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aer==0.8.2->qiskit) (1.21.2)
# Requirement already satisfied: quandl in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (3.6.1)
# Requirement already satisfied: dlx<=1.0.4 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (1.0.4)
# Requirement already satisfied: fastdtw<=0.3.4 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (0.3.4)
# Requirement already satisfied: pandas in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (1.3.3)
# Requirement already satisfied: sympy>=1.3 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (1.8)
# Requirement already satisfied: setuptools>=40.1.0 in c:\programdata\anaconda3\lib\site-packages (from qiskit-aqua==0.9.5->qiskit) (52.0.0.post20210125)
# Requirement already satisfied: docplex>=2.21.207 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (2.21.207)
# Requirement already satisfied: yfinance>=0.1.62 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (0.1.63)
# Requirement already satisfied: h5py<3.3.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (3.2.1)
# Requirement already satisfied: retworkx>=0.8.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (0.10.2)
# Requirement already satisfied: psutil>=5 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (5.8.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-aqua==0.9.5->qiskit) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (2.8.1)
# Requirement already satisfied: requests>=2.19 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (2.25.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (1.26.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (1.1.0)
# Requirement already satisfied: websocket-client>=1.0.1 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (1.2.1)
# Requirement already satisfied: ply>=3.10 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-terra==0.18.2->qiskit) (3.11)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-terra==0.18.2->qiskit) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-terra==0.18.2->qiskit) (2.15.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-terra==0.18.2->qiskit) (1.1.1)
# Requirement already satisfied: dill>=0.3 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from qiskit-terra==0.18.2->qiskit) (0.3.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\programdata\anaconda3\lib\site-packages (from qiskit-terra==0.18.2->qiskit) (3.2.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from docplex>=2.21.207->qiskit-aqua==0.9.5->qiskit) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.18.2->qiskit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.18.2->qiskit) (20.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (4.0.0)
# Requirement already satisfied: cryptography>=1.3 in c:\programdata\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (3.4.7)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (1.14.5)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (2.20)
# Requirement already satisfied: joblib>=0.11 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from sympy>=1.3->qiskit-aqua==0.9.5->qiskit) (1.2.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->qiskit-aqua==0.9.5->qiskit) (2021.1)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\h&r\appdata\roaming\python\python38\site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (0.5.1)
# Requirement already satisfied: more-itertools in c:\users\h&r\appdata\roaming\python\python38\site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (8.9.0)

# %%
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in c:\users\h&r\appdata\roaming\python\python38\site-packages (2.10)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_state_city
from random import randrange
from qiskit.tools.monitor import job_monitor

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import random
import math

# %% [markdown]
# ### For  1 step  m=2

# %%
#discrete time quantum random walk with a hadamard coin
n=2
steps=1

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized
#QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])

#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'001': 5010, '111': 4990}

# %% [markdown]
# ### For 2 steps m=2

# %%
#discrete time quantum random walk with a hadamard coin
n=2
steps=2

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized
#QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])

#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'100': 2505, '110': 2561, '000': 2541, '010': 2393}

# %% [markdown]
# ### For 3 steps m=3

# %%
#discrete time quantum random walk with a hadamard coin
n=2
steps=3

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized
#QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])

#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'101': 5029, '001': 4971}

# %% [markdown]
# ### For 11 steps m=3

# %%
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_city

#discrete time quantum random walk with a hadamard coin
n=3
steps=11

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized
#QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])

#print(a)
    
display(QC.draw(output="mpl"))

# %%
state = DensityMatrix.from_instruction(QC)

# %%
plot_state_city(state,figsize=(15, 8), color=['midnightblue', 'midnightblue'],
     title="New State City")

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, figsize=(10, 2), color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'1111': 1284, '0101': 1271, '1101': 1243, '0111': 1254, '1001': 1278, '0001': 1244, '0011': 1251, '1011': 1175}

# %%
# Import Aer
from qiskit import Aer

# Run the quantum circuit on a statevector simulator backend
backend = Aer.get_backend('statevector_simulator')

# %%
# Create a Quantum Program for execution 
job = execute(QC, backend)

# %%
result = job.result()

# %%
outputstate = result.get_statevector(QC, decimals=3)
print(outputstate)
# Out:
# [ 0.+0.j -0.+0.j  0.+0.j -0.+0.j  0.+0.j -0.+0.j  0.+0.j  0.+0.j  0.+0.j
#   0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -1.+0.j]

# %% [markdown]
# ### For 11 steps m=6  Coin |+> state

# %%
#discrete time quantum random walk with a hadamard coin
n=6
steps=11

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized coin |0>

#QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])
        
#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, figsize=(10, 2), color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'0000011': 905, '1000101': 805, '0111101': 316, '1111101': 24, '1000001': 23, '0000111': 3630, '1111011': 315, '1000111': 323, '0000001': 689, '1110111': 296, '1000011': 333, '0000101': 315, '0001001': 479, '1111001': 814, '0111111': 488, '1001001': 8, '0111011': 45, '0111001': 172, '1110101': 4, '0110111': 9, '0001011': 7}

# %% [markdown]
# ### For 11 steps m=6  Coin |-> state

# %%
#discrete time quantum random walk with a hadamard coin
n=6
steps=11

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)


#initialized coin |1>
QC.x(qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])
        
#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, figsize=(10, 2), color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'1111001': 3613, '1000001': 488, '1111101': 971, '0000111': 808, '0111011': 834, '0000101': 303, '1000011': 308, '1111111': 686, '0001001': 307, '0111001': 290, '0111101': 298, '1110111': 510, '1111011': 293, '1000111': 185, '0000011': 10, '1000101': 53, '0111111': 21, '0110111': 5, '0001011': 5, '1110101': 7, '1001001': 5}

# %% [markdown]
# ### For 11 steps m=6  Coin Ugate state

# %%
from qiskit import *
# %matplotlib inline
#discrete time quantum random walk with a hadamard coin
n=6
steps=11

qpos = QuantumRegister(n,'qpos')
qcoin = QuantumRegister(1,'qcoin')
cpos = ClassicalRegister(n,'cr')
QC = QuantumCircuit(qpos, qcoin)

pi=math.pi

#initialized coin Ugate
QC.u(pi/2, 3*pi/2, 0, qcoin[0])

for i in range(steps):

#coin
    QC.h(qcoin[0])
    QC.barrier()

#increment gate operator
    for i in range(n):
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
    QC.barrier()

#decrement gate operator
  
    QC.x(qcoin[0])
    for i in range(n):
        if i+1 < n: QC.x(qpos[i+1:])
        QC.mct([qcoin[0]]+qpos[i+1:], qpos[i], None, mode='noancilla')
        if i+1 < n: QC.x(qpos[i+1:])
    QC.barrier()
a=n/2
p=math.floor(a)
#print(p)
for k in range(n):
    if(k<p):
        QC.swap(qpos[n-1-k],qpos[k])

#print(a)
    
display(QC.draw(output="mpl"))

# %%
QC.measure_all()

    # # Execute the circuit on the qasm simulator
    
job = execute(QC,Aer.get_backend('aer_simulator'),shots=10000)
counts = job.result().get_counts(QC)   
print(counts)

plot_histogram(counts, figsize=(10, 2), color='midnightblue', title="New Histogram")

#aer_sim = Aer.get_backend('aer_simulator')
#qobj = assemble(had)
#result = aer_sim.run(qobj).result()
#counts = result.get_counts()
#plot_histogram(counts)
# Out:
# {'1111001': 2150, '1000001': 232, '0000111': 2214, '1111101': 517, '0111101': 310, '0000011': 467, '1000101': 419, '0000101': 311, '1111111': 344, '1000011': 319, '0111011': 423, '1110111': 436, '1111011': 327, '0000001': 344, '1000111': 273, '0111111': 249, '0001001': 419, '0111001': 230, '0110111': 5, '1001001': 5, '0001011': 3, '1110101': 3}

# %% [markdown]
# ## IBMQ
