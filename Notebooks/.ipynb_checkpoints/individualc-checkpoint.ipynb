# %% [markdown]
# # Individual Contributions
#
#
#
#
#
#
#
#
#
#
#
# ## Hossein Khabazipour
#
# 1.Obtain the best possible U gate to apply on coin qubit with optimized $\theta $ and $\phi $ angles, done in matlab software to obtain the best possible distribution on all positions. (This is different from what has been done so far and it was presented by me for the first time in current project)
#
# 2.Create project Summary,Our New Work,Outcomes,Challenges,Suggestion part of  jupyter file
#
# 3.Analytical study of discrete quantum walk relations in  single coin model.
#
# 4.Classical walk implementation in Python
#
# 5.Modification of LSB & MSB in the quantum walk circuit
#
# 6.Obtaining output state and unitary matrix of quantum walk circuit  and use it in MATLAB software to optimize the ugate parameters.
#
# 7.Comparison of optimized outputs(optimized ugate operator applied on coin qubit ) with non-optimal mode when only simple Hadamard operator is applied on coin qubit to initialize it.
#
# 8.Extract instruction sets and use it to check in IBM composer to display output state and bloch sphere on the IBM site
#
# 9.Implementation of the circuit in real space (on IBM real quantom computer)
#
# 10.Provide and arrange the code as a comprehensive library in qw class to call each of the functions in an unified form  to run the items mentioned previously
#
# 11.Display output in 3d city plot for better display of outputs
#
# 12. Preparing final report in git and uploading on GitHub repository and
#
#
#
#
# ## Mostafa Shabani
#
#
# 1-Define and write project proposal
#
# 2-Introduce some references for quantum walk and active participation in discussions, especially in the quantum code implementation of the algorithm.
#
# 3-Coordinate and project dividing into parts between team members
#
# 4-Quantum Qiskit code implementation of the algorithm in the most general case (desired number of positions and steps) with different initializing coin qubit on a circular path.
#
# 5-Final edit and review  of the project content files
#
# 6-Participate in arranging the final reporting of the project
#
#
#
# ## Hayede Zarei
#
#
# 1-Introducing references for Content production for the classic and quantum walk sections.
#
# 2-Collaborated on analytical review of theory and content production of the classical random walk.
#
# 3-Collaborated on analytical review of theory and content production of the quantum random walk.
#
# 4-Content production of quantum search section
#
# 5-list Jupyter notebook files
#
#
# ## Mohsen Izadyari
#
# 1-Prepare the contents of the classic walk and Quantum walk in the Jupyter files
#
# 2-Text translation from the original language into English in the content production and project reports sections
#
# 3-Content production of quantum decision-making section
#
# 4-Modeling Prison's dilemma based on quantum walk algorithm in qiskit
